# %%
# import all the important libraries:
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load the dataset:
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
#EDA

df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
df.tail(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
df.select_dtypes(include='number').columns.tolist()
# Out:
# ['SeniorCitizen', 'tenure', 'MonthlyCharges']

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
# data visualization:
numeric_col = ['tenure','MonthlyCharges','TotalCharges']
for col in numeric_col:
    plt.figure(figsize = (6,4))
    sns.histplot(df[col],kde = True,bins = 20)

# %%
df.select_dtypes(include='object').columns.tolist()
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_32512\3152244773.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include='object').columns.tolist()
# ['customerID',
#  'gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
categorical_col = [
 'gender',
 'Partner',
 'Dependents',
 'PhoneService',
 'MultipleLines',
 'InternetService',
 'OnlineSecurity',
 'OnlineBackup',
 'DeviceProtection',
 'TechSupport',
 'StreamingTV',
 'StreamingMovies',
 'Contract',
 'PaperlessBilling',
 'PaymentMethod','SeniorCitizen' ]
for col in categorical_col:
    plt.figure(figsize = (6,4))
    sns.countplot(x = df[col],data = df,hue = df["Churn"])

# %%
numeric_col = ['tenure','MonthlyCharges','TotalCharges']
for col in numeric_col:
    plt.figure(figsize = (6,4))
    sns.boxplot(df[col])

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
# data cleaning:
df_cleaned = df.copy()
df_cleaned
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df_cleaned['TotalCharges'].head(50)
# Out:
# 0       29.85
# 1     1889.50
# 2      108.15
# 3     1840.75
# 4      151.65
# 5      820.50
# 6     1949.40
# 7      301.90
# 8     3046.05
# 9     3487.95
# 10     587.45
# 11     326.80
# 12    5681.10
# 13    5036.30
# 14    2686.05
# 15    7895.15
# 16    1022.95
# 17    7382.25
# 18     528.35
# 19    1862.90
# 20      39.65
# 21     202.25
# 22      20.15
# 23    3505.10
# 24    2970.30
# 25    1530.60
# 26    4749.15
# 27      30.20
# 28    6369.45
# 29    1093.10
# 30    6766.95
# 31     181.65
# 32    1874.45
# 33      20.20
# 34      45.25
# 35    7251.70
# 36     316.90
# 37    3548.30
# 38    3549.25
# 39    1105.40
# 40     475.70
# 41    4872.35
# 42     418.25
# 43    4861.45
# 44     981.45
# 45    3906.70
# 46      97.00
# 47     144.15
# 48    4217.80
# 49    4254.10
# Name: TotalCharges, dtype: float64

# %%
df_cleaned['TotalCharges'] = pd.to_numeric(df_cleaned['TotalCharges'], errors='coerce')
df_cleaned.dropna(subset=['TotalCharges'], inplace=True)

# %%
df_cleaned.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='str')

# %%
df_cleaned.shape
# Out:
# (7032, 21)

# %%
df_cleaned.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_cleaned.drop_duplicates(inplace=True)

# %%
df_cleaned.shape
# Out:
# (7032, 21)

# %%
# Count duplicate rows
df_cleaned.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_cleaned.drop('customerID',axis = 1,inplace = True)

# %%
df_cleaned.select_dtypes(include='object').columns.tolist()
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_32512\3716649391.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df_cleaned.select_dtypes(include='object').columns.tolist()
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
# encoding
# lable encoding:
# first check the value_counts of each col
col_label = [
 'gender',
 'Partner',
 'Dependents',
 'PhoneService',
 'MultipleLines',
 'InternetService',
 'OnlineSecurity',
 'OnlineBackup',
 'DeviceProtection',
 'TechSupport',
 'StreamingTV',
 'StreamingMovies',
 'Contract',
 'PaperlessBilling',
 'PaymentMethod',
 'Churn']
for col in col_label:
    print(f"\n{col}")
    print(df_cleaned[col].value_counts())
# Out:
# gender
# gender
# Male      3549
# Female    3483
# Name: count, dtype: int64
#
# Partner
# Partner
# No     3639
# Yes    3393
# Name: count, dtype: int64
#
# Dependents
# Dependents
# No     4933
# Yes    2099
# Name: count, dtype: int64
#
# PhoneService
# PhoneService
# Yes    6352
# No      680
# Name: count, dtype: int64
#
# MultipleLines
# MultipleLines
# No                  3385
# Yes                 2967
# No phone service     680
# Name: count, dtype: int64
#
# InternetService
# InternetService
# Fiber optic    3096
# DSL            2416
# No             1520
# Name: count, dtype: int64
#
# OnlineSecurity
# OnlineSecurity
# No                     3497
# Yes                    2015
# No internet service    1520
# Name: count, dtype: int64
#
# OnlineBackup
# OnlineBackup
# No                     3087
# Yes                    2425
# No internet service    1520
# Name: count, dtype: int64
#
# DeviceProtection
# DeviceProtection
# No                     3094
# ...

# %%
# now apply label encoding:
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
labelencoder = ['gender','Partner','Dependents','PhoneService','PaperlessBilling','Churn']
for col in labelencoder:
    df_cleaned[col] = le.fit_transform(df_cleaned[col])

# %%
df_cleaned
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
df_cleaned = pd.get_dummies(
    df_cleaned,
    columns=[
        'MultipleLines',
        'InternetService',
        'OnlineSecurity',
        'OnlineBackup',
        'DeviceProtection',
        'TechSupport',
        'StreamingTV',
        'StreamingMovies',
        'Contract',
        'PaymentMethod'
    ]
)

# %%
df_cleaned.astype(int)
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
df_cleaned
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
# this above method done ,i am not apply the feature engineering and selection.
# first i am training the multiple models on this data then applying feature selection and engineering and then agian train .

# %%
# multiple model training:
# before that split the data into train and test.
from sklearn.model_selection import train_test_split
X = df_cleaned.drop('Churn',axis = 1)
y = df_cleaned['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# now train the models without applying feature engineering and the model tuning.
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,accuracy_score, precision_score, recall_score

# %%
models1 = {
    'logic': LogisticRegression(),
    'knn':KNeighborsClassifier(),
    'naive':GaussianNB(),
    'DT':DecisionTreeClassifier(),
    'xgb':XGBClassifier(),
    'forest':RandomForestClassifier()
    
}
result = []
for name,model in models1.items():
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    f1_S = f1_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    recall = recall_score(y_test,y_pred)
 
    
    result.append({
    'model':name,
    "acc":accuracy,
    'f1':f1_S,
    'ps':precision,
    'rs':recall
    
})
# Out:
# c:\Users\Aditya\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
r_table = pd.DataFrame(result)
r_table
# Out:
#     model       acc        f1        ps        rs
# 0   logic  0.787491  0.553064  0.627119  0.494652
# 1     knn  0.770434  0.509863  0.589474  0.449198
# 2   naive  0.680881  0.585411  0.447109  0.847594
# 3      DT  0.722104  0.490222  0.478372  0.502674
# 4     xgb  0.774698  0.543885  0.588785  0.505348
# 5  forest  0.780384  0.539493  0.609428  0.483957

# %%
df_cleaned.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges',
#        'Churn', 'MultipleLines_No', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'InternetService_DSL',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'OnlineSecurity_No', 'OnlineSecurity_No internet service',
#        'OnlineSecurity_Yes', 'OnlineBackup_No',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No', 'DeviceProtection_No internet service',
#        'DeviceProtection_Yes', 'TechSupport_No',
#        'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No',
#        'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
#        'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year',
# ...

# %%
df_cleaned.shape
# Out:
# (7032, 41)

# %%
# now apply the feature enginnering:
df_cleaned['AvgMonthlySpend'] = df_cleaned['TotalCharges'] / (df_cleaned['tenure'] + 1)

# %%
df_cleaned
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
df_cleaned
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
df_cleaned['TenureGroup'] = pd.cut(
    df_cleaned['tenure'],
    bins=[0,12,24,48,72],
    labels=['0-1 Year','1-2 Years','2-4 Years','4-6 Years']
)

# %%
df_cleaned
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
print(df_cleaned['tenure'].min())
print(df_cleaned['tenure'].max())
print(df_cleaned['tenure'].dtype)
print(df_cleaned['tenure'].isnull().sum())
# Out:
# 1
# 72
# int64
# 0

# %%
df_cleaned.select_dtypes(include='object').columns.tolist()
# Out:
# []

# %%
df_cleaned['TenureGroup'].value_counts()
# Out:
# TenureGroup
# 4-6 Years    2239
# 0-1 Year     2175
# 2-4 Years    1594
# 1-2 Years    1024
# Name: count, dtype: int64

# %%
print(df_cleaned.columns.tolist())
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn', 'MultipleLines_No', 'MultipleLines_No phone service', 'MultipleLines_Yes', 'InternetService_DSL', 'InternetService_Fiber optic', 'InternetService_No', 'OnlineSecurity_No', 'OnlineSecurity_No internet service', 'OnlineSecurity_Yes', 'OnlineBackup_No', 'OnlineBackup_No internet service', 'OnlineBackup_Yes', 'DeviceProtection_No', 'DeviceProtection_No internet service', 'DeviceProtection_Yes', 'TechSupport_No', 'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No', 'StreamingTV_No internet service', 'StreamingTV_Yes', 'StreamingMovies_No', 'StreamingMovies_No internet service', 'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year', 'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)', 'PaymentMethod_Credit card (automatic)', 'PaymentMethod_Electronic check', 'PaymentMethod_Mailed check', 'AvgMonthlySpend'
# ...

# %%
df_cleaned = pd.get_dummies(df_cleaned,columns = ['TenureGroup'])

# %%
df_cleaned
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
from scipy.stats import chi2_contingency
import pandas as pd

categorical_cols = [
    'gender',
    'SeniorCitizen',
    'Partner',
    'Dependents',
    'PhoneService',
    'PaperlessBilling',
    'MultipleLines_No',
    'MultipleLines_No phone service',
    'MultipleLines_Yes',
    'InternetService_DSL',
    'InternetService_Fiber optic',
    'InternetService_No',
    'OnlineSecurity_No',
    'OnlineSecurity_No internet service',
    'OnlineSecurity_Yes',
    'OnlineBackup_No',
    'OnlineBackup_No internet service',
    'OnlineBackup_Yes',
    'DeviceProtection_No',
    'DeviceProtection_No internet service',
    'DeviceProtection_Yes',
    'TechSupport_No',
    'TechSupport_No internet service',
    'TechSupport_Yes',
    'StreamingTV_No',
    'StreamingTV_No internet service',
    'StreamingTV_Yes',
    'StreamingMovies_No',
    'StreamingMovies_No internet service',
    'StreamingMovies_Yes',
    'Contract_Month-to-month',
    'Contract_One year',
    'Contract_Two year',
    'PaymentMethod_Bank transfer (automatic)',
    'PaymentMethod_Credit card (automatic)',
    'PaymentMethod_Electronic check',
    'PaymentMethod_Mailed check',
    'TenureGroup_0-1 Year',
    'TenureGroup_1-2 Years',
    'TenureGroup_2-4 Years',
    'TenureGroup_4-6 Years'
]

alpha = 0.05
results = []

for feature in categorical_cols:

    contingency_table = pd.crosstab(
        df_cleaned[feature],
        df_cleaned['Churn']
    )

    chi2, p_value, dof, expected = chi2_contingency(contingency_table)

    decision = "Keep" if p_value < alpha else "Drop"

    results.append([feature, chi2, p_value, decision])

chi_df = pd.DataFrame(
    results,
    columns=['Feature', 'Chi_Square', 'P_Value', 'Decision']
)

chi_df = chi_df.sort_values(
    by='Chi_Square',
    ascending=False
)

chi_df
# Out:
#                                     Feature   Chi_Square        P_Value  \
# 30                  Contract_Month-to-month  1149.104315  7.023468e-252
# 12                        OnlineSecurity_No   822.073779  8.568504e-181
# 21                           TechSupport_No   796.510254  3.095970e-175
# 37                     TenureGroup_0-1 Year   716.837108  6.522677e-158
# 10              InternetService_Fiber optic   663.356457  2.782210e-146
# 32                        Contract_Two year   637.848351  9.815072e-141
# 35           PaymentMethod_Electronic check   637.588697  1.117802e-140
# 15                          OnlineBackup_No   502.321566  2.970618e-111
# 40                    TenureGroup_4-6 Years   488.948899  2.412794e-108
# 18                      DeviceProtection_No   445.608558   6.513662e-99
# 28      StreamingMovies_No internet service   362.947849   6.422521e-81
# 25          StreamingTV_No internet service   362.947849   6.422521e-81
# ...

# %%
df_cleaned
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  Churn  ...  \
# ...

# %%
print(X.min().min())  # it checks is any less than 0 ,value present
# Out:
# 0

# %%
df_cleaned.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges',
#        'Churn', 'MultipleLines_No', 'MultipleLines_No phone service',
#        'MultipleLines_Yes', 'InternetService_DSL',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'OnlineSecurity_No', 'OnlineSecurity_No internet service',
#        'OnlineSecurity_Yes', 'OnlineBackup_No',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No', 'DeviceProtection_No internet service',
#        'DeviceProtection_Yes', 'TechSupport_No',
#        'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No',
#        'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
#        'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year',
# ...

# %%
from scipy.stats import pearsonr
import pandas as pd

target = 'Churn'

numerical_cols = [
    'tenure',
    'MonthlyCharges',
    'TotalCharges',
    'AvgMonthlySpend'
]

pearson_results = []

for feature in numerical_cols:

    corr, p_value = pearsonr(
        df_cleaned[feature],
        df_cleaned[target]
    )

    if abs(corr) >= 0.30:
        decision = "Keep"
    else:
        decision = "Drop"

    pearson_results.append([
        feature,
        corr,
        p_value,
        decision
    ])

pearson_df = pd.DataFrame(
    pearson_results,
    columns=[
        'Feature',
        'Pearson_Correlation',
        'P_Value',
        'Decision'
    ]
)

pearson_df = pearson_df.sort_values(
    by='Pearson_Correlation',
    key=abs,
    ascending=False
)

print(pearson_df)
# Out:
#            Feature  Pearson_Correlation        P_Value Decision
# 0           tenure            -0.354049  9.437650e-207     Keep
# 2     TotalCharges            -0.199484   4.876866e-64     Drop
# 1   MonthlyCharges             0.192858   6.760843e-60     Drop
# 3  AvgMonthlySpend             0.070992   2.527860e-09     Drop

# %%
selected_features = [
    # Numerical (Pearson)
    'tenure',

    # Categorical (Chi-Square)
    'SeniorCitizen',
    'Partner',
    'Dependents',
    'PaperlessBilling',
    'MultipleLines_No',
    'MultipleLines_Yes',
    'InternetService_DSL',
    'InternetService_Fiber optic',
    'InternetService_No',
    'OnlineSecurity_No',
    'OnlineSecurity_No internet service',
    'OnlineSecurity_Yes',
    'OnlineBackup_No',
    'OnlineBackup_No internet service',
    'OnlineBackup_Yes',
    'DeviceProtection_No',
    'DeviceProtection_No internet service',
    'DeviceProtection_Yes',
    'TechSupport_No',
    'TechSupport_No internet service',
    'TechSupport_Yes',
    'StreamingTV_No',
    'StreamingTV_No internet service',
    'StreamingTV_Yes',
    'StreamingMovies_No',
    'StreamingMovies_No internet service',
    'StreamingMovies_Yes',
    'Contract_Month-to-month',
    'Contract_One year',
    'Contract_Two year',
    'PaymentMethod_Bank transfer (automatic)',
    'PaymentMethod_Credit card (automatic)',
    'PaymentMethod_Electronic check',
    'PaymentMethod_Mailed check',
    'TenureGroup_0-1 Year',
       'TenureGroup_2-4 Years', 
    'TenureGroup_4-6 Years'
    
]

df_selected = df_cleaned[selected_features + ['Churn']]

df_selected
# Out:
#       tenure  SeniorCitizen  Partner  Dependents  PaperlessBilling  \
# 0          1              0        1           0                 1
# 1         34              0        0           0                 0
# 2          2              0        0           0                 1
# 3         45              0        0           0                 0
# 4          2              0        0           0                 1
# ...      ...            ...      ...         ...               ...
# 7038      24              0        1           1                 1
# 7039      72              0        1           1                 1
# 7040      11              0        1           1                 1
# 7041       4              1        1           0                 1
# 7042      66              0        0           0                 1
#
#       MultipleLines_No  MultipleLines_Yes  InternetService_DSL  \
# 0                False              False                 True
# ...

# %%
df_selected
# Out:
#       tenure  SeniorCitizen  Partner  Dependents  PaperlessBilling  \
# 0          1              0        1           0                 1
# 1         34              0        0           0                 0
# 2          2              0        0           0                 1
# 3         45              0        0           0                 0
# 4          2              0        0           0                 1
# ...      ...            ...      ...         ...               ...
# 7038      24              0        1           1                 1
# 7039      72              0        1           1                 1
# 7040      11              0        1           1                 1
# 7041       4              1        1           0                 1
# 7042      66              0        0           0                 1
#
#       MultipleLines_No  MultipleLines_Yes  InternetService_DSL  \
# 0                False              False                 True
# ...

# %%
df_selected.shape
# Out:
# (7032, 39)

# %%
df_selected.astype(int)
# Out:
#       tenure  SeniorCitizen  Partner  Dependents  PaperlessBilling  \
# 0          1              0        1           0                 1
# 1         34              0        0           0                 0
# 2          2              0        0           0                 1
# 3         45              0        0           0                 0
# 4          2              0        0           0                 1
# ...      ...            ...      ...         ...               ...
# 7038      24              0        1           1                 1
# 7039      72              0        1           1                 1
# 7040      11              0        1           1                 1
# 7041       4              1        1           0                 1
# 7042      66              0        0           0                 1
#
#       MultipleLines_No  MultipleLines_Yes  InternetService_DSL  \
# 0                    0                  0                    1
# ...

# %%
# scaling:
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df_selected['tenure'] = scaler.fit_transform(df_selected[['tenure']])

# %%
df_selected
# Out:
#         tenure  SeniorCitizen  Partner  Dependents  PaperlessBilling  \
# 0    -1.280248              0        1           0                 1
# 1     0.064303              0        0           0                 0
# 2    -1.239504              0        0           0                 1
# 3     0.512486              0        0           0                 0
# 4    -1.239504              0        0           0                 1
# ...        ...            ...      ...         ...               ...
# 7038 -0.343137              0        1           1                 1
# 7039  1.612573              0        1           1                 1
# 7040 -0.872808              0        1           1                 1
# 7041 -1.158016              1        1           0                 1
# 7042  1.368109              0        0           0                 1
#
#       MultipleLines_No  MultipleLines_Yes  InternetService_DSL  \
# 0                False              False                 True
# ...

# %%
# so train the multiple model again and choose one
from sklearn.model_selection import train_test_split

W = df_selected.drop('Churn', axis=1)
g = df_selected['Churn']

W_train, W_test, g_train, g_test = train_test_split(
    W,
    g,
    test_size=0.2,
    random_state=42,

)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix
)

models = {
    'Logistic Regression': LogisticRegression(),
    'KNN': KNeighborsClassifier(),
    'Random Forest': RandomForestClassifier(random_state=42),
    'XGBoost': XGBClassifier(random_state=42, eval_metric='logloss')
}

results = []

for name, model in models.items():

    model.fit(W_train, g_train)

    y_pred = model.predict(W_test)

    results.append({
        'Model': name,
        'Accuracy': accuracy_score(g_test, y_pred),
        'Precision': precision_score(g_test, y_pred),
        'Recall': recall_score(g_test, y_pred),
        'F1 Score': f1_score(g_test, y_pred),
        'Confusion Matrix': confusion_matrix(g_test, y_pred)
    })

results
# Out:
# [{'Model': 'Logistic Regression',
#   'Accuracy': 0.7889125799573561,
#   'Precision': 0.6431226765799256,
#   'Recall': 0.4625668449197861,
#   'F1 Score': 0.5381026438569206,
#   'Confusion Matrix': array([[937,  96],
#          [201, 173]])},
#  {'Model': 'KNN',
#   'Accuracy': 0.7654584221748401,
#   'Precision': 0.5647058823529412,
#   'Recall': 0.5133689839572193,
#   'F1 Score': 0.5378151260504201,
#   'Confusion Matrix': array([[885, 148],
#          [182, 192]])},
#  {'Model': 'Random Forest',
#   'Accuracy': 0.7853589196872779,
#   'Precision': 0.6176470588235294,
#   'Recall': 0.5053475935828877,
#   'F1 Score': 0.5558823529411765,
#   'Confusion Matrix': array([[916, 117],
#          [185, 189]])},
#  {'Model': 'XGBoost',
#   'Accuracy': 0.7640369580668088,
#   'Precision': 0.5583333333333333,
#   'Recall': 0.5374331550802139,
#   'F1 Score': 0.547683923705722,
#   'Confusion Matrix': array([[874, 159],
#          [173, 201]])}]

# %%
feature_result = pd.DataFrame(results)
feature_result
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score  \
# 0  Logistic Regression  0.788913   0.643123  0.462567  0.538103
# 1                  KNN  0.765458   0.564706  0.513369  0.537815
# 2        Random Forest  0.785359   0.617647  0.505348  0.555882
# 3              XGBoost  0.764037   0.558333  0.537433  0.547684
#
#            Confusion Matrix
# 0   [[937, 96], [201, 173]]
# 1  [[885, 148], [182, 192]]
# 2  [[916, 117], [185, 189]]
# 3  [[874, 159], [173, 201]]

# %%
# hyper parameter tuning :
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression

logic = LogisticRegression()
forest = RandomForestClassifier()
xgb = XGBClassifier()

from sklearn.model_selection import GridSearchCV

classi = GridSearchCV(logic,{
        'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l2'],
    'solver': ['lbfgs', 'liblinear'],
    'max_iter': [100, 500, 1000]
    },
    cv=5  
)

# %%
classi.fit(W,g)
# Out:
# c:\Users\Aditya\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Aditya\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# ...

# %%
results = pd.DataFrame(classi.cv_results_)
results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.010356      0.000894         0.001609        0.000134     0.01
# 1        0.009097      0.000319         0.001482        0.000077     0.01
# 2        0.009513      0.000518         0.001433        0.000137     0.01
# 3        0.009115      0.000344         0.001463        0.000082     0.01
# 4        0.009455      0.000556         0.001471        0.000143     0.01
# 5        0.009198      0.000564         0.001588        0.000079     0.01
# 6        0.016165      0.001472         0.001457        0.000058     0.10
# 7        0.011549      0.000377         0.001708        0.000090     0.10
# 8        0.015254      0.000973         0.001528        0.000135     0.10
# 9        0.011716      0.000633         0.001686        0.000219     0.10
# 10       0.015333      0.001339         0.001501        0.000084     0.10
# 11       0.012178      0.000340         0.001319        0.000041     0.10
# ...

# %%
results[['mean_test_score','params','rank_test_score']]
# Out:
#     mean_test_score                                             params  \
# 0          0.802474  {'C': 0.01, 'max_iter': 100, 'penalty': 'l2', ...
# 1          0.801763  {'C': 0.01, 'max_iter': 100, 'penalty': 'l2', ...
# 2          0.802474  {'C': 0.01, 'max_iter': 500, 'penalty': 'l2', ...
# 3          0.801763  {'C': 0.01, 'max_iter': 500, 'penalty': 'l2', ...
# 4          0.802474  {'C': 0.01, 'max_iter': 1000, 'penalty': 'l2',...
# 5          0.801763  {'C': 0.01, 'max_iter': 1000, 'penalty': 'l2',...
# 6          0.803612  {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', '...
# 7          0.804323  {'C': 0.1, 'max_iter': 100, 'penalty': 'l2', '...
# 8          0.803612  {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...
# 9          0.804323  {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...
# 10         0.803612  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', ...
# 11         0.804323  {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2', ...
# ...

# %%
print(classi.best_params_)
print(classi.best_score_)
# Out:
# {'C': 1, 'max_iter': 100, 'penalty': 'l2', 'solver': 'lbfgs'}
# 0.8054606059319335

# %%
best_model = classi.best_estimator_

y_pred = best_model.predict(W_test)
y_prob = best_model.predict_proba(W_test)[:, 1]

from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

print(classification_report(g_test, y_pred))
print("ROC-AUC:", roc_auc_score(g_test, y_prob))
print("Confusion Matrix:\n", confusion_matrix(g_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.86      1033
#            1       0.64      0.46      0.54       374
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.68      0.70      1407
# weighted avg       0.78      0.79      0.78      1407
#
# ROC-AUC: 0.8333937288723463
# Confusion Matrix:
#  [[938  95]
#  [202 172]]

# %%
classi1 = GridSearchCV(
    forest,
    {
        'n_estimators': [100],
        'max_depth': [10, None],
        'min_samples_split': [2] ,
        'min_samples_leaf': [1],
        'max_features': ['sqrt', 'log2']
    },
    cv=5,
    n_jobs=-1
)
classi1.fit(W,g)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [10, None],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1], 'min_samples_split': [2],
#                          'n_estimators': [100]})

# %%
results = pd.DataFrame(classi1.cv_results_)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.443255      0.016213         0.028164        0.002886
# 1       0.405794      0.013942         0.027182        0.002237
# 2       0.597778      0.008771         0.030808        0.002148
# 3       0.414436      0.076031         0.021459        0.004588
#
#   param_max_depth param_max_features  param_min_samples_leaf  \
# 0              10               sqrt                       1
# 1              10               log2                       1
# 2            None               sqrt                       1
# 3            None               log2                       1
#
#    param_min_samples_split  param_n_estimators  \
# 0                        2                 100
# 1                        2                 100
# 2                        2                 100
# 3                        2                 100
#
#                                               params  split0_test_score  \
# ...

# %%
print(classi1.best_params_)
print(classi1.best_score_)
# Out:
# {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.7980645441760916

# %%
best_model = classi1.best_estimator_

y_pred = best_model.predict(W_test)
y_prob = best_model.predict_proba(W_test)[:, 1]

from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

print(classification_report(g_test, y_pred))
print("ROC-AUC:", roc_auc_score(g_test, y_prob))
print("Confusion Matrix:\n", confusion_matrix(g_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89      1033
#            1       0.75      0.59      0.66       374
#
#     accuracy                           0.84      1407
#    macro avg       0.80      0.76      0.78      1407
# weighted avg       0.83      0.84      0.83      1407
#
# ROC-AUC: 0.9158595234274295
# Confusion Matrix:
#  [[959  74]
#  [154 220]]

# %%
classi2 = GridSearchCV(
    xgb,
    {
    'n_estimators': [100, 200],
    'max_depth': [3, 5],
    'learning_rate': [0.1, 0.2],
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'gamma': [0, 0.1]
},
    cv=5)

# %%
classi2.fit(W,g)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=True, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
# ...

# %%
results = pd.DataFrame(classi1.cv_results_)
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.443255      0.016213         0.028164        0.002886
# 1       0.405794      0.013942         0.027182        0.002237
# 2       0.597778      0.008771         0.030808        0.002148
# 3       0.414436      0.076031         0.021459        0.004588
#
#   param_max_depth param_max_features  param_min_samples_leaf  \
# 0              10               sqrt                       1
# 1              10               log2                       1
# 2            None               sqrt                       1
# 3            None               log2                       1
#
#    param_min_samples_split  param_n_estimators  \
# 0                        2                 100
# 1                        2                 100
# 2                        2                 100
# 3                        2                 100
#
#                                               params  split0_test_score  \
# ...

# %%
print(classi1.best_params_)
print(classi1.best_score_)
# Out:
# {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.7980645441760916

# %%
# so the logistic regression model has the highest accuracy than these 2 .

# %%
W
# Out:
#         tenure  SeniorCitizen  Partner  Dependents  PaperlessBilling  \
# 0    -1.280248              0        1           0                 1
# 1     0.064303              0        0           0                 0
# 2    -1.239504              0        0           0                 1
# 3     0.512486              0        0           0                 0
# 4    -1.239504              0        0           0                 1
# ...        ...            ...      ...         ...               ...
# 7038 -0.343137              0        1           1                 1
# 7039  1.612573              0        1           1                 1
# 7040 -0.872808              0        1           1                 1
# 7041 -1.158016              1        1           0                 1
# 7042  1.368109              0        0           0                 1
#
#       MultipleLines_No  MultipleLines_Yes  InternetService_DSL  \
# 0                False              False                 True
# ...

# %%
best_model = classi2.best_estimator_

y_pred = best_model.predict(W_test)
y_prob = best_model.predict_proba(W_test)[:, 1]

from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix

print(classification_report(g_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_prob))
print("Confusion Matrix:\n", confusion_matrix(g_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      1033
#            1       0.68      0.51      0.58       374
#
#     accuracy                           0.81      1407
#    macro avg       0.76      0.71      0.73      1407
# weighted avg       0.80      0.81      0.80      1407
#
# ROC-AUC: 0.8537125137831248
# Confusion Matrix:
#  [[943  90]
#  [183 191]]

# %%
# now take the pkl file of the model we choosed.
# we choose the logistic regression model.

import joblib 
joblib.dump(models['Random Forest'],'customer_churn_model.pkl')
joblib.dump(W.columns,'col_w.pkl')
joblib.dump(scaler,'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
W.columns.tolist()
# Out:
# ['tenure',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'PaperlessBilling',
#  'MultipleLines_No',
#  'MultipleLines_Yes',
#  'InternetService_DSL',
#  'InternetService_Fiber optic',
#  'InternetService_No',
#  'OnlineSecurity_No',
#  'OnlineSecurity_No internet service',
#  'OnlineSecurity_Yes',
#  'OnlineBackup_No',
#  'OnlineBackup_No internet service',
#  'OnlineBackup_Yes',
#  'DeviceProtection_No',
#  'DeviceProtection_No internet service',
#  'DeviceProtection_Yes',
#  'TechSupport_No',
#  'TechSupport_No internet service',
#  'TechSupport_Yes',
#  'StreamingTV_No',
#  'StreamingTV_No internet service',
#  'StreamingTV_Yes',
#  'StreamingMovies_No',
#  'StreamingMovies_No internet service',
#  'StreamingMovies_Yes',
#  'Contract_Month-to-month',
#  'Contract_One year',
#  'Contract_Two year',
#  'PaymentMethod_Bank transfer (automatic)',
#  'PaymentMethod_Credit card (automatic)',
#  'PaymentMethod_Electronic check',
#  'PaymentMethod_Mailed check',
# ...

# %%
W.shape
# Out:
# (7032, 38)

# %%
import joblib

scaler = joblib.load("scaler.pkl")
cols = joblib.load("col_w.pkl")

print("=== SCALER FEATURE NAMES ===")
print(scaler.feature_names_in_.tolist())

print("\n=== EXPECTED COLUMNS (cols.pkl) ===")
print(cols)
# Out:
# === SCALER FEATURE NAMES ===
# ['tenure']
#
# === EXPECTED COLUMNS (cols.pkl) ===
# Index(['tenure', 'SeniorCitizen', 'Partner', 'Dependents', 'PaperlessBilling',
#        'MultipleLines_No', 'MultipleLines_Yes', 'InternetService_DSL',
#        'InternetService_Fiber optic', 'InternetService_No',
#        'OnlineSecurity_No', 'OnlineSecurity_No internet service',
#        'OnlineSecurity_Yes', 'OnlineBackup_No',
#        'OnlineBackup_No internet service', 'OnlineBackup_Yes',
#        'DeviceProtection_No', 'DeviceProtection_No internet service',
#        'DeviceProtection_Yes', 'TechSupport_No',
#        'TechSupport_No internet service', 'TechSupport_Yes', 'StreamingTV_No',
#        'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
#        'StreamingMovies_Yes', 'Contract_Month-to-month', 'Contract_One year',
#        'Contract_Two year', 'PaymentMethod_Bank transfer (automatic)',
# ...

# %%
print(type(scaler))
print(scaler)
# Out:
# <class 'sklearn.preprocessing._data.StandardScaler'>
# StandardScaler()
